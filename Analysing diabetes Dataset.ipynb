# %%
import pandas as pd

# %%
# the file path
file_path = r"C:\Users\hp2021\Desktop\BI\analysis\Dataset of Diabetes .csv"

# Read the CSV file
data = pd.read_csv(file_path)

# %%
data
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# 1    23.0     N
# ...

# %%
# Show first rows of data (5 by default)
data.head()
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
# Show ttl nbr of rows and columns of data 
data.shape
# Out:
# (1000, 14)

# %%
# shows the index of the datase
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# Show names of columns
data.columns
# Out:
# Index(['ID', 'No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG',
#        'HDL', 'LDL', 'VLDL', 'BMI', 'CLASS'],
#       dtype='object')

# %%
# Show columns of data and their type
data.dtypes
# Out:
# ID             int64
# No_Pation      int64
# Gender        object
# AGE            int64
# Urea         float64
# Cr             int64
# HbA1c        float64
# Chol         float64
# TG           float64
# HDL          float64
# LDL          float64
# VLDL         float64
# BMI          float64
# CLASS         object
# dtype: object

# %%
# Show unique values in a column of data 
data["AGE"].unique()
# Out:
# array([50, 26, 33, 45, 48, 43, 32, 31, 30, 49, 42, 39, 41, 44, 47, 36, 38,
#        46, 35, 40, 59, 51, 57, 63, 25, 60, 77, 54, 34, 55, 28, 56, 52, 69,
#        73, 61, 58, 53, 66, 68, 62, 64, 67, 70, 79, 76, 65, 75, 20, 71],
#       dtype=int64)

# %%
# Show the total nbr of unique values in a column of data 
data.nunique()
# data["AGE"].nunique()
# Out:
# ID           800
# No_Pation    961
# Gender         3
# AGE           50
# Urea         110
# Cr           113
# HbA1c        111
# Chol          77
# TG            69
# HDL           48
# LDL           65
# VLDL          60
# BMI           64
# CLASS          5
# dtype: int64

# %%
# Show ttl nbr of non null values in each column of data 
#data["AGE"].count()
data.count()
# Out:
# ID           1000
# No_Pation    1000
# Gender       1000
# AGE          1000
# Urea         1000
# Cr           1000
# HbA1c        1000
# Chol         1000
# TG           1000
# HDL          1000
# LDL          1000
# VLDL         1000
# BMI          1000
# CLASS        1000
# dtype: int64

# %%
# Show ttl nbr of non null values in each column of data 
data.Gender.value_counts()
#data.count()
# Out:
# M    565
# F    434
# f      1
# Name: Gender, dtype: int64

# %%
# provides basic info about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB

# %%
# filtering 
data[data.Gender == 'M']
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# 7    421      34227      M   48   4.7  47    4.0   2.9  0.8  0.9  1.6   0.4
# 8    670      34229      M   43   2.6  67    4.0   3.8  0.9  2.4  3.7   1.0
# 15   566      34236      M   50   5.5  74    5.0   3.6  1.1  1.0  2.1   0.5
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 1    23.0     N
# 4    21.0     N
# ...

# %%
#group by
data.groupby('Gender').get_group('M')
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# 7    421      34227      M   48   4.7  47    4.0   2.9  0.8  0.9  1.6   0.4
# 8    670      34229      M   43   2.6  67    4.0   3.8  0.9  2.4  3.7   1.0
# 15   566      34236      M   50   5.5  74    5.0   3.6  1.1  1.0  2.1   0.5
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 1    23.0     N
# 4    21.0     N
# ...

# %%
#Chech if there s a null value
data.isnull()
# Out:
#         ID  No_Pation  Gender    AGE   Urea     Cr  HbA1c   Chol     TG  \
# 0    False      False   False  False  False  False  False  False  False
# 1    False      False   False  False  False  False  False  False  False
# 2    False      False   False  False  False  False  False  False  False
# 3    False      False   False  False  False  False  False  False  False
# 4    False      False   False  False  False  False  False  False  False
# ..     ...        ...     ...    ...    ...    ...    ...    ...    ...
# 995  False      False   False  False  False  False  False  False  False
# 996  False      False   False  False  False  False  False  False  False
# 997  False      False   False  False  False  False  False  False  False
# 998  False      False   False  False  False  False  False  False  False
# 999  False      False   False  False  False  False  False  False  False
#
#        HDL    LDL   VLDL    BMI  CLASS
# 0    False  False  False  False  False
# ...

# %%
#Chech if there s a null value
data.isnull().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
# rename the column No_Pation to PatientNbr (only in thid command)
data.rename(columns = {'No_Pation' : 'PatientNbr'})
# Out:
#       ID  PatientNbr Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502       17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735       34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420       47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680       87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504       34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...         ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200      454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671      876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669       87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99       24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248       24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# 0    24.0     N
# ...

# %%
# rename the column No_Pation to PatientNbr permanintly
data.rename(columns = {'No_Pation' : 'PatientNbr'}, inplace = True)

# %%
# what is the mean age 
data.AGE.mean()
# Out:
# 53.528

# %%
# what is the standard deviation (quantifies how much individual data points in a dataset deviate from the mean (average) of the dataset) of age
data.Urea.std()
# Out:
# 2.935165441524571

# %%
# what is the variance of BMI in this data 
data.BMI.var()
# Out:
# 24.62529577537525

# %%
# all instances where age 30 was recorded
data.AGE.value_counts()
# Out:
# 55    181
# 60     88
# 54     84
# 51     51
# 61     49
# 56     48
# 52     44
# 50     43
# 59     32
# 57     31
# 58     30
# 63     29
# 53     25
# 30     20
# 49     19
# 45     16
# 33     16
# 40     13
# 44     13
# 35     11
# 66     11
# 47     10
# 42     10
# 48     10
# 31      9
# 39      9
# 68      8
# 62      8
# 73      8
# 43      8
# 64      7
# 69      6
# 67      6
# 38      6
# 41      5
# 34      5
# 36      4
# 76      4
# 77      4
# 28      3
# 46      3
# 26      2
# 70      2
# 65      2
# 75      2
# 25      1
# 79      1
# 32      1
# 20      1
# 71      1
# Name: AGE, dtype: int64

# %%
# all instances where age 30 was recorded (filtering)
data[data['AGE'] == 30]
# Out:
#       ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 12    82      46815      F   30   3.0   42    4.1   4.9  1.3  1.2  3.2   0.5
# 17   676      87654      F   30   3.0   42    4.1   4.9  1.3  1.2  3.2   0.5
# 25   470      46675      F   30   3.0   45    4.1   4.9  1.3  1.2  3.2   0.5
# 26   494      45566      M   30   4.8   80    5.5   5.5  1.8  1.2  3.5   0.8
# 78   134      45367      F   30   3.6   61    5.4   6.5  1.8  1.5  4.2   0.8
# 90   154      45369      M   30   5.5   79    5.6   3.9  1.6  0.9  3.3   0.8
# 129  466      26665      F   30   5.7   53    6.0   5.4  1.7  1.4  3.3   0.7
# 131  688      87660      F   30   5.7   53    6.0   5.4  1.7  1.4  3.3   0.7
# 151  133      45366      M   30  17.1  344    6.0   4.9  1.6  1.7  2.5   0.7
# 153  146      45368      M   30   6.0   97    5.8   4.2  1.7  1.2  2.2   0.8
# 157   18      23977      M   30   7.1   81    6.7   4.1  1.1  1.2  2.4   8.1
# ...

# %%
# all instances where Gender f or F was recorded (str.contains)
data[data['Gender'].str.lower().str.contains('f')]
# Out:
#       ID  No_Pation Gender  AGE  Urea   Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 2    420      47975      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7   46    4.9   4.2  0.9  2.4  1.4   0.5
# 5    634      34224      F   45   2.3   24    4.0   2.9  1.0  1.0  1.5   0.4
# 6    721      34225      F   50   2.0   50    4.0   3.6  1.3  0.9  2.1   0.6
# ..   ...        ...    ...  ...   ...  ...    ...   ...  ...  ...  ...   ...
# 982  184     454316      F   54   5.0   88    6.8   5.1  2.1  1.1  3.0   1.0
# 984  187     454316      F   60   5.0   70    8.1   5.2  3.3  1.4  0.6   3.0
# 985  188     454316      F   75  10.3  113    8.6   4.2  1.6  0.9  2.6   0.7
# 990  194     454316      F   57   4.1   70    9.3   5.3  3.3  1.0  1.4   1.3
# 991  195       4543      f   55   4.1   34   13.9   5.4  1.6  1.6  3.1   0.7
#
#       BMI CLASS
# 0    24.0     N
# ...

# %%
# all instances where BMI is above 27 and age is 73 
data[(data['BMI'] > 27) & (data['AGE'] == 73)]
# Out:
#       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG   HDL  LDL  VLDL  \
# 256  224      24046      M   73   4.3  79    6.9   5.3  1.4  1.50  3.2   0.6
# 260  510      34290      M   73   4.3  79    6.9   5.3  1.4  1.50  3.2   0.6
# 277  251      24055      M   73   4.3  67   10.3   4.2  1.9  1.95  9.9   0.7
# 284  306       5474      M   73   4.3  67   10.3   4.2  1.9  1.95  9.9   0.7
# 887   50     789451      M   73   6.1  83   12.0   5.0  3.3  1.30  2.4   1.5
#
#       BMI CLASS
# 256  28.0     Y
# 260  28.0     Y
# 277  34.0     Y
# 284  34.0     Y
# 887  33.0     Y

# %%
#what is the mean value of each column againt each age 
data.groupby('AGE').mean()
# Out:
#              ID     No_Pation       Urea          Cr      HbA1c      Chol  \
# AGE
# 20   177.000000  4.536400e+04   4.600000   70.000000   9.600000  4.100000
# 25   147.000000  4.536500e+04  10.000000   35.000000   4.000000  4.300000
# 26   432.000000  3.981850e+04   6.000000   70.500000   6.850000  3.600000
# 28   135.000000  1.779837e+05   3.700000   65.000000   7.300000  5.133333
# 30   320.700000  8.976535e+04   5.855000   88.800000   6.100000  5.095000
# 31   415.555556  1.451818e+05   3.655556   51.666667   6.922222  4.522222
# 32   759.000000  3.423000e+04   3.600000   28.000000   4.000000  3.800000
# 33   475.062500  8.859644e+04   3.618750   53.500000   6.031250  4.243750
# 34   425.600000  4.283360e+04   4.780000   76.800000   6.320000  5.360000
# 35   143.636364  9.688700e+04   4.754545   59.363636   6.490909  4.800000
# 36   242.750000  2.106850e+07   4.350000   65.250000   6.425000  5.050000
# 38   445.000000  6.940233e+04   4.616667   59.166667   7.383333  4.750000
# ...

# %%
# what is the min nd max value of each column againt age 
#data.groupby('AGE').min() 
data.groupby('AGE').max()
# Out:
#       ID  No_Pation Gender  AGE  Urea  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI  \
# Cr
# 6     72      86745      F   31   3.9   5.40   4.4  1.8  1.1  2.6   0.8  22.0
# 20   738      34370      F   56   2.0  11.70   5.5  5.3  0.9  2.0   1.2  33.0
# 22   779      34505      F   56   2.8  14.60   5.8  2.0  1.8  1.8   1.5  33.0
# 23   750      45646      F   61   2.2   9.96   6.6  4.2  1.2  4.1   1.7  29.0
# 24   634      35645      F   55   2.3   6.70   4.8  1.0  1.9  2.6   1.1  27.0
# ..   ...        ...    ...  ...   ...    ...   ...  ...  ...  ...   ...   ...
# 327   50      34556      M   53  14.9  11.00   5.9  8.7  1.0  3.0   3.4  33.0
# 344  133      45366      M   30  17.1   6.00   4.9  1.6  1.7  2.5   0.7  21.0
# 370  534      34305      M   57   4.6   6.80   6.1  6.0  2.5  3.5   1.1  37.0
# 401  540      34455      F   61  24.0   7.00   4.3  2.9  0.4  2.7   1.3  36.6
# 800  266      51623      M   60  20.8   9.10   6.6  2.9  1.2  4.3   1.3  35.0
#
#     CLASS
# Cr
# 6       N
# ...
